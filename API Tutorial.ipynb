# %%
import requests

# %%
response = requests.get('https://google.com/')

# %%
print(response.status_code)
# Out:
# 200

# %%
url = "https://baconator-bacon-ipsum.p.rapidapi.com/"

querystring = {"type":"meat-and-filler"}

headers = {
	"X-RapidAPI-Host": "baconator-bacon-ipsum.p.rapidapi.com",
	"X-RapidAPI-Key": "ffb3cb0e08msh5deb5a2647a00f6p141fe5jsnff3235bef6ba"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# ["Ullamco swine alcatra, spare ribs quis corned beef ut enim.  Ullamco commodo elit boudin irure duis, shank exercitation tri-tip ipsum frankfurter consequat minim pork chop short loin.  Buffalo rump ground round nostrud veniam id ut.  In ball tip consequat salami.  Pork pork loin sausage anim sirloin, porchetta brisket kevin.","Turkey irure landjaeger chicken, chislic tri-tip tail veniam deserunt andouille.  Bresaola biltong pariatur picanha pastrami.  Pork chop eiusmod bresaola venison ribeye qui pork tail do spare ribs incididunt.  Picanha sirloin cow tri-tip jerky.  Aliqua jowl dolore spare ribs, hamburger sed consequat nostrud sirloin.","Shankle ground round elit pork chop minim cow leberkas pork belly sirloin sed rump tenderloin.  Biltong officia pancetta pariatur beef commodo.  Porchetta ut biltong, beef ribs reprehenderit swine drumstick sed cupidatat.  Anim ut in burgdoggen adipisicing do reprehenderit kevin aliqua hamburger buffalo.  Duis exercitation sunt pig, laboris bris
# ...

# %%
params = {"type":"meat-and-filler", "format": "json"}
response = requests.get(f"https://baconator-bacon-ipsum.p.rapidapi.com/", params=params,
 headers={
   "X-RapidAPI-Host": "baconator-bacon-ipsum.p.rapidapi.com",
   "X-RapidAPI-Key": "ffb3cb0e08msh5deb5a2647a00f6p141fe5jsnff3235bef6ba"
 }
)
print (type(response.json()))
print(response.json())
# Out:
# <class 'list'>
# ...

# %%
endpoint = "https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos"
>>> # Replace DEMO_KEY below with your own key if you generated one.
>>> api_key = "DEMO_KEY"
>>> query_params = {"api_key": api_key, "earth_date": "2020-07-01"}
>>> response = requests.get(endpoint, params=query_params)
>>> response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'photos': [{'id': 754118,
#    'sol': 2809,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/fcam/FLB_646868981EDR_F0810628FHAZ00337M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
#   {'id': 754119,
#    'sol': 2809,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/fcam/FRB_646868981EDR_F0810628FHAZ00337M_.JPG',
#    'earth_date': '2020-07-01',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active'}},
# ...

# %%
photos = response.json()["photos"]
>>> print(f"Found {len(photos)} photos")
# Out:
# Found 12 photos

# %%
photos[4]["img_src"]
# Out:
# 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02809/opgs/edr/rcam/RRB_646869036EDR_F0810628RHAZ00337M_.JPG'
